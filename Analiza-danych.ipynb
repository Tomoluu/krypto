# %%
import pandas as pd
import numpy as np
import datetime
import time
import os
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# '/home/tomo/krypto'

# %%
#df = pd.read_csv(r'C:\Users\Tomo\Documents\Krypto\archive\xlmusd.csv')

# %%
df = pd.read_csv('/home/tomo/krypto/archive/xlmusd.csv')

# %%
names = ['time', 'open', 'close', 'high', 'low', 'volume']
df.set_index('time', inplace=True)
df.sort_index(inplace=True)
df['time'] = df.index
df = df.reindex(columns=names)
df.index = pd.to_datetime(df.index, unit='ms')
df['slope']=np.nan
df['signal']=np.nan
df['min']=range(len(df))
df
# Out:
#                               time     open    close     high      low  \
# time
# 2018-05-01 11:27:00  1525174020000  0.45000  0.44989  0.45000  0.44989
# 2018-05-01 11:28:00  1525174080000  0.46660  0.46660  0.46660  0.46660
# 2018-05-01 11:29:00  1525174140000  0.45000  0.45000  0.45000  0.45000
# 2018-05-01 11:30:00  1525174200000  0.45998  0.45998  0.45998  0.45998
# 2018-05-01 11:31:00  1525174260000  0.45878  0.45878  0.45878  0.45878
# ...                            ...      ...      ...      ...      ...
# 2021-04-10 06:20:00  1618035600000  0.50138  0.49995  0.50191  0.49995
# 2021-04-10 06:21:00  1618035660000  0.50000  0.49989  0.50000  0.49989
# 2021-04-10 06:22:00  1618035720000  0.50000  0.50000  0.50000  0.50000
# 2021-04-10 06:26:00  1618035960000  0.50064  0.50064  0.50064  0.50064
# 2021-04-10 06:29:00  1618036140000  0.50065  0.50065  0.50065  0.50065
#
#                            volume  slope  signal     min
# time
# ...

# %%
print(datetime.datetime.now())

minutes = 240 #czas w jakim będziemy badać wzrosty w minutach
buy = 0.06 #minimalny wzrost w ciągu <minutes> w celu kupna
sell = -0.02 #minimalny spadek w ciągu <minutes> w celu sprzedaży

x = range(minutes)

for i in range(len(df)-minutes):
    element = int(i)
    
    base = df['close'][element]
    y = df['close'][0+i:minutes+i]/base
    slope = np.polyfit(x, y, 1)[0]*minutes
    df['slope'][element] = slope
    
    if(slope > buy):
        df['signal'][element] = 3
    elif(slope < sell):
        df['signal'][element] = 1
    else:
        df['signal'][element] = 2
        
    if(i % 1000 == 0):
        print(i)
        
plt.hist(df.slope, density=False, bins=40)  # density=False would make counts
plt.ylabel('Probability')
plt.xlabel('Data')

print(df.signal.value_counts())

print(datetime.datetime.now())
# Out:
# 2021-04-16 18:54:54.330093
# <ipython-input-4-c391d928f025>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['slope'][element] = slope
# <ipython-input-4-c391d928f025>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signal'][element] = 2
# 0
# <ipython-input-4-c391d928f025>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signal'][element] = 1
# 1000
# ...

# %%
buy = 0.2 #minimalny wzrost w ciągu <minutes> w celu kupna
sell = -0.02 #minimalny spadek w ciągu <minutes> w celu sprzedaży

x = range(minutes)

for i in range(len(df)-minutes):
    element = int(i)
    
    if(slope > buy):
        df['signal'][element] = 2
    elif(slope < sell):
        df['signal'][element] = 3
    else:
        df['signal'][element] = 1
        
    if(i % 1000 == 0):
        print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4a2d7f79faa6> in <module>
#       2 sell = -0.02 #minimalny spadek w ciągu <minutes> w celu sprzedaży
#       3
# ----> 4 x = range(minutes)
#       5
#       6 for i in range(len(df)-minutes):
#
# NameError: name 'minutes' is not defined

# %%
df.to_csv('/home/tomo/krypto/dane/xlmusd2.csv')

# %%
df = pd.read_csv('/home/tomo/krypto/dane/xlmusd2.csv')

# %%
df = df.set_index('time')

# %%
df
# Out:
#                             time.1     open    close     high      low  \
# time
# 2018-05-01 11:27:00  1525174020000  0.45000  0.44989  0.45000  0.44989
# 2018-05-01 11:28:00  1525174080000  0.46660  0.46660  0.46660  0.46660
# 2018-05-01 11:29:00  1525174140000  0.45000  0.45000  0.45000  0.45000
# 2018-05-01 11:30:00  1525174200000  0.45998  0.45998  0.45998  0.45998
# 2018-05-01 11:31:00  1525174260000  0.45878  0.45878  0.45878  0.45878
# ...                            ...      ...      ...      ...      ...
# 2021-04-10 06:20:00  1618035600000  0.50138  0.49995  0.50191  0.49995
# 2021-04-10 06:21:00  1618035660000  0.50000  0.49989  0.50000  0.49989
# 2021-04-10 06:22:00  1618035720000  0.50000  0.50000  0.50000  0.50000
# 2021-04-10 06:26:00  1618035960000  0.50064  0.50064  0.50064  0.50064
# 2021-04-10 06:29:00  1618036140000  0.50065  0.50065  0.50065  0.50065
#
#                            volume     slope  signal     min
# time
# ...

# %%
plt.hist(df.slope, bins=100)
plt.figure(figsize=(1,1))
plt.show()

# %%
df.signal.value_counts()
# Out:
# 1.0    141880
# 3.0     89569
# 2.0     35841
# Name: signal, dtype: int64

# %%
#df.index = pd.to_datetime(df.index, unit='ms')

fig, ax = plt.subplots(1, 1, figsize=(18, 5))

ax.plot(df['close']['2021':])
ax.set_xlabel('date', fontsize=16)
ax.set_ylabel('BTC price [USD]', fontsize=16)
ax.set_title('Bitcoin closing price from {} to {}'.format(df.index[0], df.index[-1]))
ax.grid()

plt.show()

fig, ax = plt.subplots(1, 1, figsize=(18, 5))

ax.plot(df['close']['2021':])
ax.set_xlabel('date', fontsize=16)
ax.set_ylabel('Stellar price [USD]', fontsize=16,)
ax.set_title('Bitcoin closing price from {} to {}'.format(d.index[0], d.index[-1]))
ax.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/matplotlib/category.py in _str_is_convertible(val)
#     192         try:
# --> 193             float(val)
#     194         except ValueError:
#
# ValueError: could not convert string to float: '2021-02-11 06:59:00'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a25fb37874e2> in <module>
#       3 fig, ax = plt.subplots(1, 1, figsize=(18, 5))
#       4
# ----> 5 ax.plot(df['close']['2021':])
#       6 ax.set_xlabel('date', fontsize=16)
#       7 ax.set_ylabel('BTC price [USD]', fontsize=16)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
x = df.index[222640:222645]
y = df['close'][222640:222645]

#use green as color for individual points
plt.plot(x, y, color='grey')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#use red as color for regression line
plt.plot(x, m*x+b, color='green')
plt.title(m)
print(m*len(df['time'][222100:222800]))
print(slope)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-a672c7f854f1> in <module>
#       6
#       7 #obtain m (slope) and b(intercept) of linear regression line
# ----> 8 m, b = np.polyfit(x, y, 1)
#       9
#      10 #use red as color for regression line
#
# ~\Anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     587     """
#     588     order = int(deg) + 1
# --> 589     x = NX.asarray(x) + 0.0
#     590     y = NX.asarray(y) + 0.0
#     591
#
# TypeError: ufunc add cannot use operands with types dtype('<M8[ns]') and dtype('float64')
